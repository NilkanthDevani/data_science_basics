# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'country':['United States','Russia','France','Germany','Israel',
                            'United Kingdom','Netherlands',
                            'China','Spain','Italy','South Korea',
                            'Turkey','Ukraine','Switzerland','Norway'], 
                   'spending':np.random.uniform(size=15) })

ordered_df = df.sort_values(by='spending')
my_range=range(1,len(df.index)+1)

plt.hlines(y=my_range, xmin=0, xmax=ordered_df['spending'], colors='skyblue')
plt.plot(ordered_df['spending'], my_range, "o")

plt.yticks(my_range, ordered_df['country'])
plt.title('A vertical lolipop', loc='center', fontsize=17)
plt.xlabel('spending in millions')
plt.ylabel('country')
# Out:
# Text(0, 0.5, 'country')

# %%
df = pd.DataFrame({'country':['United States','Russia','France','Germany','Israel',
                            'United Kingdom','Netherlands',
                            'China','Spain','Italy','South Korea',
                            'Turkey','Ukraine','Switzerland','Norway'], 
                   'spending':np.random.uniform(size=15) })

ordered_df = df.sort_values(by='spending')


# my_range=range(1,len(df.index)+1)



plt.hlines(y=ordered_df['country'],xmin=0, xmax=ordered_df['spending'], colors='skyblue')
plt.plot(ordered_df['spending'],ordered_df['country'], "o")

# plt.yticks(my_range, ordered_df['country'])
plt.title('A vertical lolipop', loc='center', fontsize=17)
plt.xlabel('spending in millions')
plt.ylabel('country')
# Out:
# Text(0, 0.5, 'country')

# %%
pd_fuel = pd.read_csv('D:\\Jupyter\\classroom\\pie_chart_data.csv')
pd_fuel.columns
# Out:
# Index(['Engine Fuel Type', 'Number of Cars'], dtype='object')

# %%
# sns.color_palette('Set2')

# %%
sns.set_palette('Paired')

# %%
plt.figure(figsize=(8,6))
plt.pie(pd_fuel['Number of Cars'],
       labels=pd_fuel['Engine Fuel Type'],
       autopct='%.f%%',
       textprops={'size': 'x-large',
                 'fontweight':'bold',
                 'rotation':'30',
                 'color':'w'})
plt.legend()
plt.show()

# %% [markdown]
# # Numeric Data

# %% [markdown]
# # Histogram

# %%
marks = [43.1,35.6,37.6,36.5,45.3,43.5,40.3,50.2,47.3,31.2,42.2,45.5,30.3,31.4,35.6,45.2,54.1,45.6,36.5,43.1]

# %%
plt.hist(marks, bins= list(range(28,60,2)))
plt.title('Histogram of result')
plt.xticks(list(range(28,60,5)))
plt.xlabel('Mark')
plt.ylabel('No. of student')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(6,6))
plt.hist(pd_fuel['Number of Cars'], bins=12, color='#108A99' )
plt.title('Histogram of result')
plt.xlabel('Mark')
plt.ylabel('No. of student')
sns.despine() # removes the top and right border of our graph

plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
 iris = pd.read_csv('D:\\Jupyter\\classroom\\iris.csv')

# %%
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(sns.distplot, "Petal.Width") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="Species", size=5) \
    .map(sns.distplot, "Petal.Length") \
    .add_legend();
plt.show();

# %% [markdown]
# # Box plot

# %%
iris = pd.read_csv('D:\\Jupyter\\classroom\\iris.csv')
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
sns.boxplot(x="Species", y="Sepal.Length", data=iris)
plt.show()

# %% [markdown]
# # For scatter plot

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, gdp, color='red', marker='o', linestyle='solid')
plt.show();

# %% [markdown]
# # Heat Map

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
cr_df = sns.load_dataset('car_crashes')

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

# %%
crash_mx = cr_df.corr()

# %%
sns.heatmap(crash_mx,
           annot=True,
           cmap='PuOr')
plt.show()
